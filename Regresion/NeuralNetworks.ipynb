# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2025
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# Las redes neuronales profundas (deep learning) han ganado mucha popularidad en los últimos años, especialmente para problemas complejos, como el reconocimiento de imágenes, el procesamiento del lenguaje natural y otras aplicaciones que requieren modelos potentes.
#
# Sin embargo, las redes neuronales básicas también pueden usarse en problemas de aprendizaje supervisado más simples, como regresión o clasificación, AUNQUE hay varias razones por las cuales otros algoritmos son más comunes en estos casos...
#
# 1. Complejidad computacional
# 2. Sobreajuste (Overfitting)
# 3. Necesidad de más datos
# 4. Tuning de Hiperparámetros (las redes neuronales tienen muchos hiperparámetros)
# 5. Interpretabilidad, son modelos de caja negra
#
# **¿Cuándo se utilizan redes neuronales en aprendizaje supervisado?**
#
# Aunque no siempre son la primera opción para problemas simples, las redes neuronales pueden ser muy útiles en problemas supervisados más complejos donde:
#
# - Hay gran cantidad de datos disponibles
# - Los problemas son no lineales
# - Hay tareas de percepción involucradas (como visión por computadora, reconocimiento de voz o procesamiento de lenguaje natural), donde las redes neuronales profundas sobresalen.

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %% [markdown]
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - RELU: es la más utilizada para capas ocultas. Es fácil de calcular, lo que la hace más rápida para entrenar. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Leaky RELU: Similar a ReLU, pero permite valores negativos pequeños cuando x≤0, lo que evita que las neuronas queden completamente inactivas.
# - Evita Sigmoid y Tanh en las capas ocultas
#
# **¿Cómo elegir la función de activación para las capas de salida?**
#
# - Lineal: Para problemas de regresión donde la salida es un valor continuo.
# - Sigmoidal: típicamente para problemas de clasificación binaria.
# - Softmax: Para problemas de clasificación multiclase
#
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# - Problemas sencillos: Una sola capa oculta suele ser suficiente para capturar patrones simples.
# - Problemas más complejos (con relaciones no lineales más complicadas): Dos capas ocultas pueden ser útiles
#
# En la práctica, la mayoría de los problemas sencillos no necesitan más de 1 o 2 capas ocultas.
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# - Un buen punto de partida es comenzar con un número de neuronas que sea similar o cercano al número de características de entrada.
# - Para problemas simples, puedes comenzar con entre 4 y 16 neuronas por capa.
# - Si los datos tienen una cantidad moderada de complejidad o son no lineales, podrías aumentar a 32 o 64 neuronas en la capa oculta.
# - Evita tener muchas más neuronas que características de entrada, ya que eso puede llevar a un sobreajuste.
# - En redes con múltiples capas ocultas, una estrategia común es que las capas posteriores tengan menos neuronas que las capas iniciales. Esto es porque las primeras capas extraen más características, mientras que las capas más profundas se enfocan en combinarlas.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas
#
#
# **¿Por qué el deep learning no funciona tan bien en problemas clásicos de regresión/clasificación?**
#
# Gran parte del éxito de las redes neuronales modernas proviene de su capacidad para explotar la naturaleza compositiva del mundo. Es decir, en problemas de percepción como el análisis de imágenes o audio, las características tienen un orden (espacial o temporal) y los patrones locales se agregan para formar conceptos y objetos de nivel superior (por ejemplo, la imagen de un automóvil está hecha de ruedas y otras partes, que están hechas de características visuales de nivel inferior, que están hechas de formas básicas como bordes, círculos y líneas, etc.).
#
# Las redes neuronales modernas, como las redes neuronales convolucionales (CNN), aprovechan esto aprendiendo características cada vez más abstractas en las capas más profundas.
#
# Por el contrario, los problemas de regresión clásicos constan de una serie de características no ordenadas, y el valor objetivo se puede predecir bastante bien con un modelo lineal/no lineal superficial de las características de entrada. En cierto sentido, esta propiedad composicional presente en problemas como la clasificación de imágenes o el reconocimiento de voz no está presente en problemas como "Predecir los ingresos de un individuo en función de su sexo, edad, nacionalidad, grado académico, tamaño de la familia...".

# %% [markdown]
# ## Ejemplo: Eficiencia de Energia
#
# Se busca analizar la eficiencia energética de los edificios.
#
# Se realizaron análisis energéticos utilizando 12 tipos de edificios diferentes simulados en Ecotect.
#
# Los edificios se diferencian en cuanto a la superficie con cristales, la distribución del área acristalada y la orientación, entre otros parámetros.
#
# Se simularon varios escenarios en función de las características antes mencionadas para obtener 768 formas de edificios.
#
# El conjunto de datos comprende 768 muestras y 8 características, con el objetivo de predecir dos respuestas con valor real.
#
# Información de atributos:
# - X1 Relative Compactness
# - X2 Surface Area
# - X3 Wall Area
# - X4 Roof Area
# - X5 Overall Height
# - X6 Orientation
# - X7 Glazing Area
# - X8 Glazing Area Distribution
#
# Targets:
# - Y1: Heating Load (in Wh)
# - Y2: Cooling Load (in Wh)
# -
# Las características son numéricas y representan diversas características físicas del edificio, mientras que las variables objetivo representan la energía necesaria para calefacción y enfriamiento.

# %%
##pip install tensorflow

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ENB2012_data.csv")

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %%
#Matriz de correlaciones
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Correlaciones con el target
correlation_target = df.corr()[['Y1','Y2']]
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_target, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Target')
plt.show()

# %%
#Distribucion de las varialbes
sns.pairplot(df)

# %% [markdown]
# ### Modelado

# %% [markdown]
# Vamos a usar una red compartida con dos salidas (cooling and heating load), ya que los dos targets están físicamente relacionados y la red puede aprender representaciones compartidas.
#
# Algunos tips para empezar la arquitectura inicial de la red:
#
# **a. Entrada y salida**
#
# - Entradas: 8 características → tamaño de capa de entrada = 8
# - Salidas: 2 objetivos → tamaño de capa de salida = 2
#
# **b. Capas ocultas**
#
# Por lo general, comienzas poco a poco y vas ampliando:
#
# - Comienza con 1 a 2 capas ocultas.
# - Numero de neuronas: entre el tamaño de entrada y salida (8) y tal vez entre 2 y 4 veces más (16–32–64).
#
# Por ejemplo:
# Input (8)
# ↓
# Dense(64, ReLU)
# ↓
# Dense(32, ReLU)
# ↓
# Dense(2, Linear)
#
# **c. Funcion de activacion**
#
# Comenzar con RELU para capas ocultas
#
# **d. Agregar Regularizacion**
#
# Agregar regularizacion si vemos overfitting (dropout)
#
# **e. Funcion de costo**
#
# MSE
#
# **f. Optimizer**
#
# Adam

# %%
X = df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']].values
y1 = df['Y1'].values  # Heating Load
y2 = df['Y2'].values  # Cooling Load

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.2, random_state=42)

# %%
# Estandarizamos los datos
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Modelo Baseline

# %%
# Capa de entrada (8 variables)
input_layer = Input(shape=(X_train.shape[1],), name='input_layer')

# Capas ocultas compartidas
layer_dense1_shared=Dense(64 , activation='relu', name='shared_dense_1')(input_layer)
layer_dense2_shared=Dense(32,activation='relu',name='shared_dense_2')(layer_dense1_shared)
layer_dropout1_shared=Dropout(0.2,name='shared_dropout_1')(layer_dense2_shared)

#Estructura para Y1 (Heating Load)
y1_dense_1=Dense(32, activation='relu',name='y1_dense_1')(layer_dropout1_shared)
y1_dropout = Dropout(0.2, name='y1_dropout')(y1_dense_1)
y1_dense2 = Dense(16, activation='relu', name='y1_dense_2')(y1_dropout)
y1_output = Dense(1, name='y1_output')(y1_dense2)

#Estructura para Y2 (Cooling Load)
y2_dense1 = Dense(32, activation='relu', name='y2_dense_1')(layer_dropout1_shared)
y2_dropout = Dropout(0.2, name='y2_dropout')(y2_dense1)
y2_dense3 = Dense(16, activation='relu', name='y2_dense_3')(y2_dropout)
y2_output = Dense(1, name='y2_output')(y2_dense3)

# %%
#  Modelo que contenga la capa de entrada y las capas de salida 
model=Model(inputs=input_layer  ,outputs=[y1_output , y2_output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_1      │ (None, 64)        │        576 │ input_layer[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_2      │ (None, 32)        │      2,080 │ shared_dense_1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dropout_1    │ (None, 32)        │          0 │ shared_dense_2[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dropout          │ (None, 32)        │          0 │ y1_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dropout          │ (None, 32)        │          0 │ y2_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_2 (Dense)  │ (None, 16)        │        528 │ y1_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_3 (Dense)  │ (None, 16)        │        528 │ y2_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │         17 │ y1_dense_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         17 │ y2_dense_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,858 (22.88 KB)
#  Trainable params: 5,858 (22.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos el modelo

model.compile(optimizer='adam', 
              loss={'y1_output': 'mse', 'y2_output': 'mse'}, 
              metrics={'y1_output': 'mae', 'y2_output': 'mae'})

# Entrenamos el modelo
history = model.fit(X_train, [y1_train, y2_train], epochs=200, batch_size=32, 
                    validation_data=(X_test, [y1_test, y2_test]))
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1253.3004 - y1_output_loss: 571.3582 - y1_output_mae: 21.6987 - y2_output_loss: 681.1856 - y2_output_mae: 24.2782 - val_loss: 1308.0431 - val_y1_output_loss: 591.9235 - val_y1_output_mae: 22.0606 - val_y2_output_loss: 726.4511 - val_y2_output_mae: 25.0449
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1208.4595 - y1_output_loss: 539.3140 - y1_output_mae: 20.9828 - y2_output_loss: 669.9945 - y2_output_mae: 24.0308 - val_loss: 1132.2163 - val_y1_output_loss: 482.6893 - val_y1_output_mae: 19.6559 - val_y2_output_loss: 658.7582 - val_y2_output_mae: 23.6745
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 978.2214 - y1_output_loss: 403.2430 - y1_output_mae: 17.7142 - y2_output_loss: 572.6238 - y2_output_mae: 21.9848 - val_loss: 599.0425 - val_y1_output_loss: 191.9123 - val_y1_output_mae: 11.1008 - val_y2_output_loss: 412.5794 - val_y2_output_mae: 18.0466
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 398.2672 - y1_output_loss: 122.8284 - y1_output_mae: 8.5085 - y2_output_loss: 274.6310 - y2_output_mae: 14.0832 - val_loss: 133.4918 - val_y1_output_loss: 71.0675 - val_y1_output_mae: 6.5546 - val_y2_output_loss: 63.1164 - val_y2_output_mae: 5.8016
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 117.6638 - y1_output_loss: 59.0460 - y1_output_mae: 5.7726 - y2_output_loss: 58.6812 - y2_output_mae: 5.7768 - val_loss: 79.7585 - val_y1_output_loss: 39.9976 - val_y1_output_mae: 4.6084 - val_y2_output_loss: 40.1011 - val_y2_output_mae: 4.6396
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 99.4223 - y1_output_loss: 47.7937 - y1_output_mae: 5.1189 - y2_output_loss: 51.4036 - y2_output_mae: 5.3707 - val_loss: 66.7241 - val_y1_output_loss: 31.6138 - val_y1_output_mae: 3.8663 - val_y2_output_loss: 35.1766 - val_y2_output_mae: 4.3278
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 89.5747 - y1_output_loss: 43.6502 - y1_output_mae: 4.7521 - y2_output_loss: 45.7907 - y2_output_mae: 5.1462 - val_loss: 61.9357 - val_y1_output_loss: 27.6311 - val_y1_output_mae: 3.5804 - val_y2_output_loss: 34.3845 - val_y2_output_mae: 4.2224
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 85.6961 - y1_output_loss: 39.3796 - y1_output_mae: 4.7548 - y2_output_loss: 46.0661 - y2_output_mae: 4.9837 - val_loss: 56.4747 - val_y1_output_loss: 25.9756 - val_y1_output_mae: 3.4454 - val_y2_output_loss: 30.6596 - val_y2_output_mae: 4.0058
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 73.6188 - y1_output_loss: 32.3924 - y1_output_mae: 4.1214 - y2_output_loss: 41.3931 - y2_output_mae: 4.7541 - val_loss: 50.9670 - val_y1_output_loss: 23.4264 - val_y1_output_mae: 3.2403 - val_y2_output_loss: 27.7174 - val_y2_output_mae: 3.7766
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 76.5906 - y1_output_loss: 32.2089 - y1_output_mae: 4.0884 - y2_output_loss: 44.3074 - y2_output_mae: 4.9634 - val_loss: 48.2377 - val_y1_output_loss: 21.5803 - val_y1_output_mae: 3.1158 - val_y2_output_loss: 26.8177 - val_y2_output_mae: 3.6809
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.4862 - y1_output_loss: 34.4388 - y1_output_mae: 4.3569 - y2_output_loss: 38.1012 - y2_output_mae: 4.6314 - val_loss: 43.6062 - val_y1_output_loss: 20.2153 - val_y1_output_mae: 2.9353 - val_y2_output_loss: 23.5425 - val_y2_output_mae: 3.4108
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 79.8005 - y1_output_loss: 38.1651 - y1_output_mae: 4.4195 - y2_output_loss: 41.6893 - y2_output_mae: 4.6760 - val_loss: 39.5015 - val_y1_output_loss: 17.8768 - val_y1_output_mae: 2.7839 - val_y2_output_loss: 21.7721 - val_y2_output_mae: 3.2821
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 70.6550 - y1_output_loss: 31.2322 - y1_output_mae: 4.1752 - y2_output_loss: 39.3222 - y2_output_mae: 4.7845 - val_loss: 35.9900 - val_y1_output_loss: 16.3895 - val_y1_output_mae: 2.6690 - val_y2_output_loss: 19.7701 - val_y2_output_mae: 3.0970
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.0876 - y1_output_loss: 28.5538 - y1_output_mae: 3.8455 - y2_output_loss: 34.4177 - y2_output_mae: 4.1899 - val_loss: 33.4548 - val_y1_output_loss: 15.5471 - val_y1_output_mae: 2.5926 - val_y2_output_loss: 18.0743 - val_y2_output_mae: 2.9891
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 65.2028 - y1_output_loss: 29.7321 - y1_output_mae: 3.9286 - y2_output_loss: 35.4522 - y2_output_mae: 4.3123 - val_loss: 31.0500 - val_y1_output_loss: 14.0819 - val_y1_output_mae: 2.4971 - val_y2_output_loss: 17.1341 - val_y2_output_mae: 2.9182
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.2038 - y1_output_loss: 24.2084 - y1_output_mae: 3.6010 - y2_output_loss: 28.0746 - y2_output_mae: 4.0023 - val_loss: 31.8791 - val_y1_output_loss: 13.8122 - val_y1_output_mae: 2.4600 - val_y2_output_loss: 18.3326 - val_y2_output_mae: 2.9693
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.4272 - y1_output_loss: 28.5726 - y1_output_mae: 3.8786 - y2_output_loss: 30.0634 - y2_output_mae: 3.9958 - val_loss: 25.7783 - val_y1_output_loss: 11.9850 - val_y1_output_mae: 2.3482 - val_y2_output_loss: 13.9271 - val_y2_output_mae: 2.6805
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.2859 - y1_output_loss: 19.5835 - y1_output_mae: 3.2885 - y2_output_loss: 27.6154 - y2_output_mae: 3.9019 - val_loss: 25.8615 - val_y1_output_loss: 11.9981 - val_y1_output_mae: 2.2963 - val_y2_output_loss: 13.9341 - val_y2_output_mae: 2.5509
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.0211 - y1_output_loss: 21.9876 - y1_output_mae: 3.4636 - y2_output_loss: 27.8954 - y2_output_mae: 3.8821 - val_loss: 27.8478 - val_y1_output_loss: 12.4922 - val_y1_output_mae: 2.3761 - val_y2_output_loss: 15.4954 - val_y2_output_mae: 2.6096
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.3270 - y1_output_loss: 18.8412 - y1_output_mae: 3.1899 - y2_output_loss: 24.5080 - y2_output_mae: 3.6598 - val_loss: 23.0386 - val_y1_output_loss: 10.4082 - val_y1_output_mae: 2.2138 - val_y2_output_loss: 12.6027 - val_y2_output_mae: 2.4294
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.4840 - y1_output_loss: 20.1153 - y1_output_mae: 3.2529 - y2_output_loss: 24.3706 - y2_output_mae: 3.6999 - val_loss: 31.5471 - val_y1_output_loss: 15.2749 - val_y1_output_mae: 2.8874 - val_y2_output_loss: 16.5283 - val_y2_output_mae: 2.8684
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.7915 - y1_output_loss: 21.4963 - y1_output_mae: 3.4387 - y2_output_loss: 25.3526 - y2_output_mae: 3.7110 - val_loss: 28.7863 - val_y1_output_loss: 11.8611 - val_y1_output_mae: 2.4259 - val_y2_output_loss: 17.1699 - val_y2_output_mae: 2.9135
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.2624 - y1_output_loss: 22.2137 - y1_output_mae: 3.5566 - y2_output_loss: 25.0508 - y2_output_mae: 3.8121 - val_loss: 20.8493 - val_y1_output_loss: 9.6081 - val_y1_output_mae: 2.1902 - val_y2_output_loss: 11.2144 - val_y2_output_mae: 2.3077
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.4084 - y1_output_loss: 25.8832 - y1_output_mae: 3.6849 - y2_output_loss: 27.5552 - y2_output_mae: 3.8590 - val_loss: 21.1222 - val_y1_output_loss: 9.2955 - val_y1_output_mae: 2.1576 - val_y2_output_loss: 11.7954 - val_y2_output_mae: 2.4081
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.1789 - y1_output_loss: 20.5725 - y1_output_mae: 3.3477 - y2_output_loss: 26.7186 - y2_output_mae: 3.6682 - val_loss: 21.8276 - val_y1_output_loss: 9.4673 - val_y1_output_mae: 2.1311 - val_y2_output_loss: 12.4153 - val_y2_output_mae: 2.4233
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.9310 - y1_output_loss: 22.5814 - y1_output_mae: 3.5002 - y2_output_loss: 25.3586 - y2_output_mae: 3.7828 - val_loss: 22.2599 - val_y1_output_loss: 10.0119 - val_y1_output_mae: 2.1594 - val_y2_output_loss: 12.3421 - val_y2_output_mae: 2.3370
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.7137 - y1_output_loss: 16.4958 - y1_output_mae: 3.0477 - y2_output_loss: 25.2306 - y2_output_mae: 3.6279 - val_loss: 28.5949 - val_y1_output_loss: 11.6471 - val_y1_output_mae: 2.5136 - val_y2_output_loss: 17.1843 - val_y2_output_mae: 2.9610
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.5913 - y1_output_loss: 20.5867 - y1_output_mae: 3.3102 - y2_output_loss: 22.1721 - y2_output_mae: 3.5707 - val_loss: 19.1454 - val_y1_output_loss: 8.8415 - val_y1_output_mae: 2.1128 - val_y2_output_loss: 10.2816 - val_y2_output_mae: 2.2720
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.4279 - y1_output_loss: 20.6875 - y1_output_mae: 3.3882 - y2_output_loss: 26.0390 - y2_output_mae: 3.7439 - val_loss: 22.7210 - val_y1_output_loss: 9.6032 - val_y1_output_mae: 2.1737 - val_y2_output_loss: 13.2007 - val_y2_output_mae: 2.4568
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.3490 - y1_output_loss: 18.2311 - y1_output_mae: 3.2204 - y2_output_loss: 24.0714 - y2_output_mae: 3.6090 - val_loss: 20.4050 - val_y1_output_loss: 8.5408 - val_y1_output_mae: 2.0221 - val_y2_output_loss: 11.9058 - val_y2_output_mae: 2.2971
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.7473 - y1_output_loss: 18.9000 - y1_output_mae: 3.2302 - y2_output_loss: 20.8313 - y2_output_mae: 3.4403 - val_loss: 21.1068 - val_y1_output_loss: 8.8848 - val_y1_output_mae: 2.1826 - val_y2_output_loss: 12.2931 - val_y2_output_mae: 2.4877
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.2413 - y1_output_loss: 22.2585 - y1_output_mae: 3.4780 - y2_output_loss: 25.9058 - y2_output_mae: 3.7704 - val_loss: 25.4628 - val_y1_output_loss: 10.7885 - val_y1_output_mae: 2.3825 - val_y2_output_loss: 14.8503 - val_y2_output_mae: 2.6107
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.9790 - y1_output_loss: 20.5274 - y1_output_mae: 3.4442 - y2_output_loss: 22.3354 - y2_output_mae: 3.5997 - val_loss: 20.1409 - val_y1_output_loss: 9.2998 - val_y1_output_mae: 2.1624 - val_y2_output_loss: 10.8508 - val_y2_output_mae: 2.2501
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.9765 - y1_output_loss: 20.0172 - y1_output_mae: 3.3539 - y2_output_loss: 21.9252 - y2_output_mae: 3.5800 - val_loss: 19.4466 - val_y1_output_loss: 8.2450 - val_y1_output_mae: 2.0509 - val_y2_output_loss: 11.2391 - val_y2_output_mae: 2.3138
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.9256 - y1_output_loss: 19.3588 - y1_output_mae: 3.1479 - y2_output_loss: 20.5131 - y2_output_mae: 3.3897 - val_loss: 21.8837 - val_y1_output_loss: 9.8116 - val_y1_output_mae: 2.3081 - val_y2_output_loss: 12.2080 - val_y2_output_mae: 2.3983
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.6486 - y1_output_loss: 18.2422 - y1_output_mae: 3.1554 - y2_output_loss: 22.5678 - y2_output_mae: 3.5847 - val_loss: 22.4777 - val_y1_output_loss: 9.2988 - val_y1_output_mae: 2.2040 - val_y2_output_loss: 13.3430 - val_y2_output_mae: 2.4930
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.5222 - y1_output_loss: 19.3852 - y1_output_mae: 3.2714 - y2_output_loss: 22.1144 - y2_output_mae: 3.5171 - val_loss: 19.0390 - val_y1_output_loss: 8.3151 - val_y1_output_mae: 2.0260 - val_y2_output_loss: 10.8141 - val_y2_output_mae: 2.2455
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.4644 - y1_output_loss: 17.9378 - y1_output_mae: 3.1899 - y2_output_loss: 23.4414 - y2_output_mae: 3.5465 - val_loss: 22.4808 - val_y1_output_loss: 8.9319 - val_y1_output_mae: 2.2291 - val_y2_output_loss: 13.7301 - val_y2_output_mae: 2.5977
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.8925 - y1_output_loss: 18.2231 - y1_output_mae: 3.2167 - y2_output_loss: 21.6721 - y2_output_mae: 3.5360 - val_loss: 19.6029 - val_y1_output_loss: 8.0343 - val_y1_output_mae: 2.0633 - val_y2_output_loss: 11.6405 - val_y2_output_mae: 2.3745
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.2931 - y1_output_loss: 20.0251 - y1_output_mae: 3.3671 - y2_output_loss: 25.2451 - y2_output_mae: 3.6213 - val_loss: 19.6449 - val_y1_output_loss: 8.3345 - val_y1_output_mae: 2.0943 - val_y2_output_loss: 11.3455 - val_y2_output_mae: 2.3134
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.0415 - y1_output_loss: 18.9782 - y1_output_mae: 3.2327 - y2_output_loss: 25.0504 - y2_output_mae: 3.6730 - val_loss: 20.4276 - val_y1_output_loss: 8.9750 - val_y1_output_mae: 2.1795 - val_y2_output_loss: 11.5515 - val_y2_output_mae: 2.2869
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.1197 - y1_output_loss: 17.8294 - y1_output_mae: 3.1269 - y2_output_loss: 23.1789 - y2_output_mae: 3.4887 - val_loss: 19.7315 - val_y1_output_loss: 8.7907 - val_y1_output_mae: 2.0908 - val_y2_output_loss: 10.9675 - val_y2_output_mae: 2.1837
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.8270 - y1_output_loss: 18.3909 - y1_output_mae: 3.2163 - y2_output_loss: 23.4810 - y2_output_mae: 3.7215 - val_loss: 21.0957 - val_y1_output_loss: 9.2966 - val_y1_output_mae: 2.2519 - val_y2_output_loss: 11.8801 - val_y2_output_mae: 2.3327
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.9834 - y1_output_loss: 15.6150 - y1_output_mae: 2.9910 - y2_output_loss: 21.3354 - y2_output_mae: 3.4292 - val_loss: 18.5002 - val_y1_output_loss: 8.0296 - val_y1_output_mae: 2.0024 - val_y2_output_loss: 10.4978 - val_y2_output_mae: 2.1730
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.8090 - y1_output_loss: 19.4895 - y1_output_mae: 3.2553 - y2_output_loss: 22.2619 - y2_output_mae: 3.4770 - val_loss: 17.3196 - val_y1_output_loss: 7.5282 - val_y1_output_mae: 1.9300 - val_y2_output_loss: 9.7725 - val_y2_output_mae: 2.1239
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.7181 - y1_output_loss: 18.5994 - y1_output_mae: 3.2204 - y2_output_loss: 21.0287 - y2_output_mae: 3.4584 - val_loss: 22.8013 - val_y1_output_loss: 9.5323 - val_y1_output_mae: 2.3383 - val_y2_output_loss: 13.4396 - val_y2_output_mae: 2.5683
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.5945 - y1_output_loss: 23.7758 - y1_output_mae: 3.6602 - y2_output_loss: 23.7284 - y2_output_mae: 3.5665 - val_loss: 21.4127 - val_y1_output_loss: 8.1596 - val_y1_output_mae: 2.1115 - val_y2_output_loss: 13.3603 - val_y2_output_mae: 2.5714
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.2188 - y1_output_loss: 18.1663 - y1_output_mae: 3.1346 - y2_output_loss: 24.0496 - y2_output_mae: 3.4109 - val_loss: 24.4772 - val_y1_output_loss: 8.7891 - val_y1_output_mae: 2.1810 - val_y2_output_loss: 15.8832 - val_y2_output_mae: 2.8238
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.7718 - y1_output_loss: 21.3193 - y1_output_mae: 3.3437 - y2_output_loss: 20.3847 - y2_output_mae: 3.3798 - val_loss: 21.0562 - val_y1_output_loss: 8.0801 - val_y1_output_mae: 2.0510 - val_y2_output_loss: 13.1284 - val_y2_output_mae: 2.4729
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.8924 - y1_output_loss: 17.9884 - y1_output_mae: 3.1176 - y2_output_loss: 20.7856 - y2_output_mae: 3.3665 - val_loss: 21.4544 - val_y1_output_loss: 8.4163 - val_y1_output_mae: 2.1699 - val_y2_output_loss: 13.2815 - val_y2_output_mae: 2.5045
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.8948 - y1_output_loss: 16.7609 - y1_output_mae: 3.0575 - y2_output_loss: 20.0804 - y2_output_mae: 3.3200 - val_loss: 19.5954 - val_y1_output_loss: 8.0454 - val_y1_output_mae: 2.1129 - val_y2_output_loss: 11.6745 - val_y2_output_mae: 2.3374
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.7961 - y1_output_loss: 18.0377 - y1_output_mae: 3.2222 - y2_output_loss: 17.7692 - y2_output_mae: 3.1208 - val_loss: 19.7468 - val_y1_output_loss: 7.0239 - val_y1_output_mae: 1.9088 - val_y2_output_loss: 12.8574 - val_y2_output_mae: 2.4712
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.6369 - y1_output_loss: 20.3805 - y1_output_mae: 3.3768 - y2_output_loss: 20.2164 - y2_output_mae: 3.3211 - val_loss: 21.0978 - val_y1_output_loss: 9.1046 - val_y1_output_mae: 2.2674 - val_y2_output_loss: 12.1918 - val_y2_output_mae: 2.3830
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.5052 - y1_output_loss: 16.5436 - y1_output_mae: 2.9695 - y2_output_loss: 17.1221 - y2_output_mae: 3.1296 - val_loss: 19.6505 - val_y1_output_loss: 7.0687 - val_y1_output_mae: 1.8282 - val_y2_output_loss: 12.6468 - val_y2_output_mae: 2.4223
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.5323 - y1_output_loss: 18.2692 - y1_output_mae: 3.1568 - y2_output_loss: 22.1769 - y2_output_mae: 3.5637 - val_loss: 16.0838 - val_y1_output_loss: 7.1618 - val_y1_output_mae: 1.8896 - val_y2_output_loss: 8.7857 - val_y2_output_mae: 2.1526
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.2304 - y1_output_loss: 19.8302 - y1_output_mae: 3.2890 - y2_output_loss: 19.3066 - y2_output_mae: 3.3562 - val_loss: 17.1936 - val_y1_output_loss: 6.7518 - val_y1_output_mae: 1.8150 - val_y2_output_loss: 10.4487 - val_y2_output_mae: 2.1278
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.4049 - y1_output_loss: 16.0834 - y1_output_mae: 2.9626 - y2_output_loss: 16.4125 - y2_output_mae: 2.9471 - val_loss: 25.7805 - val_y1_output_loss: 8.9636 - val_y1_output_mae: 2.3008 - val_y2_output_loss: 17.0937 - val_y2_output_mae: 2.9797
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.5175 - y1_output_loss: 16.6748 - y1_output_mae: 2.9856 - y2_output_loss: 17.8371 - y2_output_mae: 3.1351 - val_loss: 18.2471 - val_y1_output_loss: 6.7796 - val_y1_output_mae: 1.8008 - val_y2_output_loss: 11.5966 - val_y2_output_mae: 2.2776
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.7317 - y1_output_loss: 16.3540 - y1_output_mae: 3.0034 - y2_output_loss: 19.3416 - y2_output_mae: 3.2564 - val_loss: 20.0645 - val_y1_output_loss: 7.3565 - val_y1_output_mae: 1.9965 - val_y2_output_loss: 12.9049 - val_y2_output_mae: 2.4442
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.6561 - y1_output_loss: 19.1072 - y1_output_mae: 3.1600 - y2_output_loss: 20.4582 - y2_output_mae: 3.3950 - val_loss: 18.0431 - val_y1_output_loss: 6.9685 - val_y1_output_mae: 1.8612 - val_y2_output_loss: 11.1304 - val_y2_output_mae: 2.2183
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.3368 - y1_output_loss: 20.6769 - y1_output_mae: 3.2919 - y2_output_loss: 20.5903 - y2_output_mae: 3.3737 - val_loss: 21.1985 - val_y1_output_loss: 8.5656 - val_y1_output_mae: 2.2369 - val_y2_output_loss: 12.7973 - val_y2_output_mae: 2.4880
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.6820 - y1_output_loss: 14.3126 - y1_output_mae: 2.7838 - y2_output_loss: 16.4131 - y2_output_mae: 3.0323 - val_loss: 17.9104 - val_y1_output_loss: 6.8573 - val_y1_output_mae: 1.8560 - val_y2_output_loss: 11.1284 - val_y2_output_mae: 2.2813
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.5528 - y1_output_loss: 15.0637 - y1_output_mae: 2.7890 - y2_output_loss: 16.6159 - y2_output_mae: 3.0077 - val_loss: 21.0025 - val_y1_output_loss: 7.8349 - val_y1_output_mae: 2.1338 - val_y2_output_loss: 13.3335 - val_y2_output_mae: 2.5933
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.0879 - y1_output_loss: 13.6645 - y1_output_mae: 2.6810 - y2_output_loss: 18.4126 - y2_output_mae: 3.1639 - val_loss: 19.8248 - val_y1_output_loss: 7.9784 - val_y1_output_mae: 2.1019 - val_y2_output_loss: 12.0451 - val_y2_output_mae: 2.3638
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3573 - y1_output_loss: 16.1260 - y1_output_mae: 2.9279 - y2_output_loss: 18.3409 - y2_output_mae: 3.1350 - val_loss: 15.5659 - val_y1_output_loss: 6.2576 - val_y1_output_mae: 1.7353 - val_y2_output_loss: 9.2984 - val_y2_output_mae: 2.0047
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.4636 - y1_output_loss: 14.8062 - y1_output_mae: 2.8476 - y2_output_loss: 18.6642 - y2_output_mae: 3.1695 - val_loss: 18.3074 - val_y1_output_loss: 7.3725 - val_y1_output_mae: 2.0463 - val_y2_output_loss: 11.0378 - val_y2_output_mae: 2.2990
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.3327 - y1_output_loss: 16.0596 - y1_output_mae: 2.9398 - y2_output_loss: 15.2881 - y2_output_mae: 2.9002 - val_loss: 19.8911 - val_y1_output_loss: 7.1192 - val_y1_output_mae: 1.9904 - val_y2_output_loss: 12.9078 - val_y2_output_mae: 2.5642
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.0929 - y1_output_loss: 17.2183 - y1_output_mae: 3.1454 - y2_output_loss: 19.7808 - y2_output_mae: 3.2562 - val_loss: 25.4136 - val_y1_output_loss: 9.1551 - val_y1_output_mae: 2.4257 - val_y2_output_loss: 16.5495 - val_y2_output_mae: 2.9994
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.4078 - y1_output_loss: 15.1961 - y1_output_mae: 2.8627 - y2_output_loss: 17.1975 - y2_output_mae: 3.0082 - val_loss: 19.3685 - val_y1_output_loss: 6.7426 - val_y1_output_mae: 1.9321 - val_y2_output_loss: 12.7992 - val_y2_output_mae: 2.5336
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.2620 - y1_output_loss: 17.5458 - y1_output_mae: 3.1094 - y2_output_loss: 18.6723 - y2_output_mae: 3.1593 - val_loss: 17.0329 - val_y1_output_loss: 6.6903 - val_y1_output_mae: 1.8956 - val_y2_output_loss: 10.4531 - val_y2_output_mae: 2.2124
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.6563 - y1_output_loss: 15.9089 - y1_output_mae: 2.9941 - y2_output_loss: 18.7611 - y2_output_mae: 3.2456 - val_loss: 22.3801 - val_y1_output_loss: 8.1089 - val_y1_output_mae: 2.2156 - val_y2_output_loss: 14.5528 - val_y2_output_mae: 2.7219
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.4822 - y1_output_loss: 14.8634 - y1_output_mae: 2.8632 - y2_output_loss: 18.5436 - y2_output_mae: 3.2081 - val_loss: 23.5540 - val_y1_output_loss: 8.2809 - val_y1_output_mae: 2.2933 - val_y2_output_loss: 15.5410 - val_y2_output_mae: 2.8438
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.4952 - y1_output_loss: 15.9035 - y1_output_mae: 2.9233 - y2_output_loss: 17.6580 - y2_output_mae: 3.1686 - val_loss: 25.2264 - val_y1_output_loss: 8.0431 - val_y1_output_mae: 2.2118 - val_y2_output_loss: 17.5215 - val_y2_output_mae: 3.0304
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.7896 - y1_output_loss: 15.4997 - y1_output_mae: 2.9093 - y2_output_loss: 15.2154 - y2_output_mae: 2.8231 - val_loss: 17.6695 - val_y1_output_loss: 6.0834 - val_y1_output_mae: 1.7740 - val_y2_output_loss: 11.6894 - val_y2_output_mae: 2.3686
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.0382 - y1_output_loss: 15.2739 - y1_output_mae: 2.8276 - y2_output_loss: 16.7605 - y2_output_mae: 2.9454 - val_loss: 17.1408 - val_y1_output_loss: 5.9043 - val_y1_output_mae: 1.7154 - val_y2_output_loss: 11.3663 - val_y2_output_mae: 2.2923
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.1793 - y1_output_loss: 15.7288 - y1_output_mae: 2.9491 - y2_output_loss: 16.4359 - y2_output_mae: 2.9961 - val_loss: 20.3602 - val_y1_output_loss: 7.0033 - val_y1_output_mae: 2.0416 - val_y2_output_loss: 13.6024 - val_y2_output_mae: 2.5998
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.9124 - y1_output_loss: 14.5955 - y1_output_mae: 2.7382 - y2_output_loss: 19.3165 - y2_output_mae: 3.2760 - val_loss: 22.4031 - val_y1_output_loss: 6.9667 - val_y1_output_mae: 2.0829 - val_y2_output_loss: 15.7028 - val_y2_output_mae: 2.9103
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.6457 - y1_output_loss: 16.0940 - y1_output_mae: 2.9633 - y2_output_loss: 18.4690 - y2_output_mae: 3.1291 - val_loss: 22.7283 - val_y1_output_loss: 7.2552 - val_y1_output_mae: 2.1010 - val_y2_output_loss: 15.7728 - val_y2_output_mae: 2.9077
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.9656 - y1_output_loss: 15.4186 - y1_output_mae: 2.8242 - y2_output_loss: 16.4713 - y2_output_mae: 3.0476 - val_loss: 21.1841 - val_y1_output_loss: 5.7631 - val_y1_output_mae: 1.7013 - val_y2_output_loss: 15.6412 - val_y2_output_mae: 2.8297
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.1964 - y1_output_loss: 16.7866 - y1_output_mae: 2.8357 - y2_output_loss: 15.5675 - y2_output_mae: 2.9879 - val_loss: 23.3052 - val_y1_output_loss: 8.0795 - val_y1_output_mae: 2.2946 - val_y2_output_loss: 15.5131 - val_y2_output_mae: 2.8936
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.2695 - y1_output_loss: 12.8464 - y1_output_mae: 2.6477 - y2_output_loss: 13.3512 - y2_output_mae: 2.7523 - val_loss: 30.2365 - val_y1_output_loss: 10.1905 - val_y1_output_mae: 2.5739 - val_y2_output_loss: 20.5161 - val_y2_output_mae: 3.3989
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.5593 - y1_output_loss: 14.7598 - y1_output_mae: 2.7778 - y2_output_loss: 15.7932 - y2_output_mae: 2.9038 - val_loss: 21.8550 - val_y1_output_loss: 7.5655 - val_y1_output_mae: 2.1094 - val_y2_output_loss: 14.5595 - val_y2_output_mae: 2.7209
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.5763 - y1_output_loss: 14.6687 - y1_output_mae: 2.8074 - y2_output_loss: 14.8612 - y2_output_mae: 2.8863 - val_loss: 16.8881 - val_y1_output_loss: 5.6732 - val_y1_output_mae: 1.7107 - val_y2_output_loss: 11.3529 - val_y2_output_mae: 2.3115
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.1831 - y1_output_loss: 15.1111 - y1_output_mae: 2.8316 - y2_output_loss: 17.0588 - y2_output_mae: 2.9846 - val_loss: 23.1501 - val_y1_output_loss: 8.2775 - val_y1_output_mae: 2.2356 - val_y2_output_loss: 15.1746 - val_y2_output_mae: 2.7638
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.1249 - y1_output_loss: 15.0731 - y1_output_mae: 2.8715 - y2_output_loss: 18.0350 - y2_output_mae: 3.0194 - val_loss: 21.7968 - val_y1_output_loss: 6.5708 - val_y1_output_mae: 2.0012 - val_y2_output_loss: 15.4603 - val_y2_output_mae: 2.9252
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.8920 - y1_output_loss: 15.1964 - y1_output_mae: 2.8044 - y2_output_loss: 17.6160 - y2_output_mae: 3.0398 - val_loss: 16.4271 - val_y1_output_loss: 5.5962 - val_y1_output_mae: 1.7426 - val_y2_output_loss: 10.9416 - val_y2_output_mae: 2.2674
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.5856 - y1_output_loss: 16.1628 - y1_output_mae: 2.8775 - y2_output_loss: 13.3556 - y2_output_mae: 2.6885 - val_loss: 15.5156 - val_y1_output_loss: 5.5880 - val_y1_output_mae: 1.7592 - val_y2_output_loss: 10.0604 - val_y2_output_mae: 2.1833
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.8966 - y1_output_loss: 16.6302 - y1_output_mae: 2.8455 - y2_output_loss: 17.2461 - y2_output_mae: 3.0492 - val_loss: 18.9351 - val_y1_output_loss: 5.6927 - val_y1_output_mae: 1.7654 - val_y2_output_loss: 13.4707 - val_y2_output_mae: 2.6079
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.1232 - y1_output_loss: 16.3672 - y1_output_mae: 2.8573 - y2_output_loss: 16.7555 - y2_output_mae: 2.9920 - val_loss: 20.0055 - val_y1_output_loss: 6.8318 - val_y1_output_mae: 1.9905 - val_y2_output_loss: 13.4277 - val_y2_output_mae: 2.5727
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.5651 - y1_output_loss: 15.2835 - y1_output_mae: 2.8701 - y2_output_loss: 15.2734 - y2_output_mae: 2.8406 - val_loss: 22.3424 - val_y1_output_loss: 6.7890 - val_y1_output_mae: 2.0346 - val_y2_output_loss: 15.8859 - val_y2_output_mae: 2.9155
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.4820 - y1_output_loss: 11.9146 - y1_output_mae: 2.4901 - y2_output_loss: 13.5377 - y2_output_mae: 2.6093 - val_loss: 18.1586 - val_y1_output_loss: 5.8765 - val_y1_output_mae: 1.8296 - val_y2_output_loss: 12.4789 - val_y2_output_mae: 2.4873
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.1718 - y1_output_loss: 12.7451 - y1_output_mae: 2.6474 - y2_output_loss: 13.4791 - y2_output_mae: 2.6331 - val_loss: 18.8295 - val_y1_output_loss: 6.5405 - val_y1_output_mae: 1.9774 - val_y2_output_loss: 12.5064 - val_y2_output_mae: 2.4973
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.9225 - y1_output_loss: 14.9749 - y1_output_mae: 2.8116 - y2_output_loss: 13.8735 - y2_output_mae: 2.7788 - val_loss: 20.5737 - val_y1_output_loss: 6.3652 - val_y1_output_mae: 1.9918 - val_y2_output_loss: 14.4187 - val_y2_output_mae: 2.7782
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.9157 - y1_output_loss: 14.3450 - y1_output_mae: 2.7464 - y2_output_loss: 16.5897 - y2_output_mae: 2.8657 - val_loss: 27.8743 - val_y1_output_loss: 10.1912 - val_y1_output_mae: 2.6010 - val_y2_output_loss: 18.1034 - val_y2_output_mae: 3.2123
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.6840 - y1_output_loss: 17.1444 - y1_output_mae: 2.9202 - y2_output_loss: 15.5413 - y2_output_mae: 2.8352 - val_loss: 18.4302 - val_y1_output_loss: 6.2511 - val_y1_output_mae: 1.9431 - val_y2_output_loss: 12.4236 - val_y2_output_mae: 2.5265
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.3252 - y1_output_loss: 13.1203 - y1_output_mae: 2.6751 - y2_output_loss: 14.2106 - y2_output_mae: 2.7531 - val_loss: 26.5474 - val_y1_output_loss: 9.1104 - val_y1_output_mae: 2.4557 - val_y2_output_loss: 17.8944 - val_y2_output_mae: 3.1904
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.8183 - y1_output_loss: 15.1061 - y1_output_mae: 2.8699 - y2_output_loss: 15.6869 - y2_output_mae: 2.8615 - val_loss: 19.1619 - val_y1_output_loss: 5.2273 - val_y1_output_mae: 1.7084 - val_y2_output_loss: 14.1661 - val_y2_output_mae: 2.7715
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.4463 - y1_output_loss: 15.5144 - y1_output_mae: 2.8534 - y2_output_loss: 14.8573 - y2_output_mae: 2.9388 - val_loss: 14.7677 - val_y1_output_loss: 5.4945 - val_y1_output_mae: 1.7841 - val_y2_output_loss: 9.4126 - val_y2_output_mae: 2.1365
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.9852 - y1_output_loss: 14.1124 - y1_output_mae: 2.6595 - y2_output_loss: 15.9360 - y2_output_mae: 2.9646 - val_loss: 20.7601 - val_y1_output_loss: 7.3198 - val_y1_output_mae: 2.1643 - val_y2_output_loss: 13.7270 - val_y2_output_mae: 2.7400
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0672 - y1_output_loss: 12.9910 - y1_output_mae: 2.6052 - y2_output_loss: 16.9937 - y2_output_mae: 2.9391 - val_loss: 14.4716 - val_y1_output_loss: 4.7258 - val_y1_output_mae: 1.5599 - val_y2_output_loss: 9.8386 - val_y2_output_mae: 2.2038
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.3944 - y1_output_loss: 16.3336 - y1_output_mae: 2.8666 - y2_output_loss: 16.9886 - y2_output_mae: 2.8576 - val_loss: 19.4437 - val_y1_output_loss: 6.0073 - val_y1_output_mae: 1.9173 - val_y2_output_loss: 13.6784 - val_y2_output_mae: 2.7011
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.4924 - y1_output_loss: 13.4184 - y1_output_mae: 2.5761 - y2_output_loss: 13.1114 - y2_output_mae: 2.6197 - val_loss: 29.5767 - val_y1_output_loss: 9.9156 - val_y1_output_mae: 2.5230 - val_y2_output_loss: 20.1832 - val_y2_output_mae: 3.4169
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.4749 - y1_output_loss: 12.9833 - y1_output_mae: 2.6293 - y2_output_loss: 16.5233 - y2_output_mae: 2.9632 - val_loss: 24.0881 - val_y1_output_loss: 7.0244 - val_y1_output_mae: 2.0829 - val_y2_output_loss: 17.4273 - val_y2_output_mae: 3.1206
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.3917 - y1_output_loss: 14.8522 - y1_output_mae: 2.7331 - y2_output_loss: 14.4742 - y2_output_mae: 2.7458 - val_loss: 29.0532 - val_y1_output_loss: 8.3937 - val_y1_output_mae: 2.2830 - val_y2_output_loss: 21.1383 - val_y2_output_mae: 3.5110
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.1232 - y1_output_loss: 13.8776 - y1_output_mae: 2.6998 - y2_output_loss: 13.2937 - y2_output_mae: 2.6016 - val_loss: 25.5133 - val_y1_output_loss: 7.4856 - val_y1_output_mae: 2.1599 - val_y2_output_loss: 18.4867 - val_y2_output_mae: 3.2360
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.6588 - y1_output_loss: 13.7225 - y1_output_mae: 2.7234 - y2_output_loss: 12.9202 - y2_output_mae: 2.6379 - val_loss: 18.8101 - val_y1_output_loss: 5.4735 - val_y1_output_mae: 1.7795 - val_y2_output_loss: 13.5694 - val_y2_output_mae: 2.6942
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.6832 - y1_output_loss: 13.7341 - y1_output_mae: 2.6974 - y2_output_loss: 16.8918 - y2_output_mae: 2.9661 - val_loss: 28.4479 - val_y1_output_loss: 9.0665 - val_y1_output_mae: 2.3945 - val_y2_output_loss: 19.8563 - val_y2_output_mae: 3.3642
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.4701 - y1_output_loss: 12.7290 - y1_output_mae: 2.4964 - y2_output_loss: 13.9458 - y2_output_mae: 2.6711 - val_loss: 26.3371 - val_y1_output_loss: 7.0478 - val_y1_output_mae: 2.0784 - val_y2_output_loss: 19.7526 - val_y2_output_mae: 3.3264
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.2392 - y1_output_loss: 14.0521 - y1_output_mae: 2.7452 - y2_output_loss: 14.1526 - y2_output_mae: 2.6625 - val_loss: 22.5838 - val_y1_output_loss: 7.1836 - val_y1_output_mae: 2.0549 - val_y2_output_loss: 15.7218 - val_y2_output_mae: 2.8579
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.4947 - y1_output_loss: 15.1738 - y1_output_mae: 2.6599 - y2_output_loss: 13.3702 - y2_output_mae: 2.6125 - val_loss: 17.4902 - val_y1_output_loss: 6.3096 - val_y1_output_mae: 1.9454 - val_y2_output_loss: 11.4402 - val_y2_output_mae: 2.3932
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.3671 - y1_output_loss: 14.3613 - y1_output_mae: 2.6838 - y2_output_loss: 14.9551 - y2_output_mae: 2.8854 - val_loss: 20.3358 - val_y1_output_loss: 4.4433 - val_y1_output_mae: 1.5397 - val_y2_output_loss: 16.2025 - val_y2_output_mae: 3.0407
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.6970 - y1_output_loss: 13.6315 - y1_output_mae: 2.6659 - y2_output_loss: 13.0981 - y2_output_mae: 2.6297 - val_loss: 24.9953 - val_y1_output_loss: 9.3806 - val_y1_output_mae: 2.4469 - val_y2_output_loss: 16.0616 - val_y2_output_mae: 2.9716
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.6030 - y1_output_loss: 11.5738 - y1_output_mae: 2.5099 - y2_output_loss: 12.9983 - y2_output_mae: 2.5270 - val_loss: 11.9358 - val_y1_output_loss: 4.1142 - val_y1_output_mae: 1.4520 - val_y2_output_loss: 7.9653 - val_y2_output_mae: 1.8623
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.3488 - y1_output_loss: 14.8263 - y1_output_mae: 2.7657 - y2_output_loss: 13.5193 - y2_output_mae: 2.7064 - val_loss: 21.7806 - val_y1_output_loss: 6.1712 - val_y1_output_mae: 1.9760 - val_y2_output_loss: 15.9930 - val_y2_output_mae: 3.0034
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.8464 - y1_output_loss: 12.0663 - y1_output_mae: 2.5884 - y2_output_loss: 11.7285 - y2_output_mae: 2.5601 - val_loss: 19.3259 - val_y1_output_loss: 5.7479 - val_y1_output_mae: 1.8631 - val_y2_output_loss: 13.9237 - val_y2_output_mae: 2.7349
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.7376 - y1_output_loss: 11.7142 - y1_output_mae: 2.4927 - y2_output_loss: 12.0031 - y2_output_mae: 2.4720 - val_loss: 19.6462 - val_y1_output_loss: 5.1983 - val_y1_output_mae: 1.7847 - val_y2_output_loss: 14.7341 - val_y2_output_mae: 2.8558
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.8754 - y1_output_loss: 13.0622 - y1_output_mae: 2.6395 - y2_output_loss: 13.9174 - y2_output_mae: 2.6565 - val_loss: 23.8635 - val_y1_output_loss: 6.8667 - val_y1_output_mae: 2.1151 - val_y2_output_loss: 17.3655 - val_y2_output_mae: 3.1563
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.3318 - y1_output_loss: 13.6996 - y1_output_mae: 2.6389 - y2_output_loss: 14.5511 - y2_output_mae: 2.6838 - val_loss: 18.3436 - val_y1_output_loss: 4.6195 - val_y1_output_mae: 1.6349 - val_y2_output_loss: 14.0390 - val_y2_output_mae: 2.7254
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.0330 - y1_output_loss: 11.8632 - y1_output_mae: 2.4482 - y2_output_loss: 13.1637 - y2_output_mae: 2.6250 - val_loss: 25.3238 - val_y1_output_loss: 7.9088 - val_y1_output_mae: 2.2082 - val_y2_output_loss: 17.9216 - val_y2_output_mae: 3.1435
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.6714 - y1_output_loss: 13.6993 - y1_output_mae: 2.6144 - y2_output_loss: 13.9618 - y2_output_mae: 2.7209 - val_loss: 21.8593 - val_y1_output_loss: 5.6445 - val_y1_output_mae: 1.8902 - val_y2_output_loss: 16.6224 - val_y2_output_mae: 3.0828
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.5230 - y1_output_loss: 10.4707 - y1_output_mae: 2.3237 - y2_output_loss: 11.0155 - y2_output_mae: 2.3599 - val_loss: 17.0277 - val_y1_output_loss: 5.2448 - val_y1_output_mae: 1.7617 - val_y2_output_loss: 12.0676 - val_y2_output_mae: 2.4654
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.7672 - y1_output_loss: 11.6594 - y1_output_mae: 2.5148 - y2_output_loss: 13.0917 - y2_output_mae: 2.7078 - val_loss: 29.7358 - val_y1_output_loss: 8.8550 - val_y1_output_mae: 2.3854 - val_y2_output_loss: 21.3747 - val_y2_output_mae: 3.5561
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.2795 - y1_output_loss: 11.4204 - y1_output_mae: 2.4396 - y2_output_loss: 13.8908 - y2_output_mae: 2.6617 - val_loss: 23.6320 - val_y1_output_loss: 7.1608 - val_y1_output_mae: 2.1353 - val_y2_output_loss: 16.8575 - val_y2_output_mae: 3.0710
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.6605 - y1_output_loss: 11.5898 - y1_output_mae: 2.4486 - y2_output_loss: 11.0547 - y2_output_mae: 2.4000 - val_loss: 21.3103 - val_y1_output_loss: 5.0937 - val_y1_output_mae: 1.7719 - val_y2_output_loss: 16.6196 - val_y2_output_mae: 3.0784
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.4851 - y1_output_loss: 12.9726 - y1_output_mae: 2.5930 - y2_output_loss: 14.4337 - y2_output_mae: 2.7150 - val_loss: 25.0879 - val_y1_output_loss: 6.4050 - val_y1_output_mae: 1.9498 - val_y2_output_loss: 19.1370 - val_y2_output_mae: 3.2263
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.7775 - y1_output_loss: 12.8916 - y1_output_mae: 2.6075 - y2_output_loss: 11.8549 - y2_output_mae: 2.4605 - val_loss: 17.1348 - val_y1_output_loss: 4.9950 - val_y1_output_mae: 1.7284 - val_y2_output_loss: 12.3864 - val_y2_output_mae: 2.5743
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.7106 - y1_output_loss: 9.8076 - y1_output_mae: 2.2550 - y2_output_loss: 12.8907 - y2_output_mae: 2.6239 - val_loss: 22.0233 - val_y1_output_loss: 6.4252 - val_y1_output_mae: 1.9983 - val_y2_output_loss: 16.0050 - val_y2_output_mae: 2.9854
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.8987 - y1_output_loss: 11.1261 - y1_output_mae: 2.4326 - y2_output_loss: 12.7492 - y2_output_mae: 2.5100 - val_loss: 22.8663 - val_y1_output_loss: 5.7749 - val_y1_output_mae: 1.8405 - val_y2_output_loss: 17.5065 - val_y2_output_mae: 3.1547
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.8145 - y1_output_loss: 11.4787 - y1_output_mae: 2.4744 - y2_output_loss: 11.3126 - y2_output_mae: 2.4487 - val_loss: 15.6381 - val_y1_output_loss: 3.9379 - val_y1_output_mae: 1.4765 - val_y2_output_loss: 11.9790 - val_y2_output_mae: 2.5321
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.2917 - y1_output_loss: 11.0106 - y1_output_mae: 2.4474 - y2_output_loss: 10.2217 - y2_output_mae: 2.3422 - val_loss: 15.7232 - val_y1_output_loss: 3.7347 - val_y1_output_mae: 1.4288 - val_y2_output_loss: 12.2813 - val_y2_output_mae: 2.4981
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.6675 - y1_output_loss: 10.7635 - y1_output_mae: 2.4619 - y2_output_loss: 9.9882 - y2_output_mae: 2.3912 - val_loss: 17.4696 - val_y1_output_loss: 5.0295 - val_y1_output_mae: 1.7564 - val_y2_output_loss: 12.8156 - val_y2_output_mae: 2.5663
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.2738 - y1_output_loss: 11.1165 - y1_output_mae: 2.4419 - y2_output_loss: 12.0915 - y2_output_mae: 2.5293 - val_loss: 26.4364 - val_y1_output_loss: 7.7617 - val_y1_output_mae: 2.1241 - val_y2_output_loss: 19.2348 - val_y2_output_mae: 3.2100
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.0972 - y1_output_loss: 12.5065 - y1_output_mae: 2.5812 - y2_output_loss: 16.5377 - y2_output_mae: 2.7860 - val_loss: 24.8396 - val_y1_output_loss: 7.1976 - val_y1_output_mae: 2.1167 - val_y2_output_loss: 18.1084 - val_y2_output_mae: 3.2121
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.3102 - y1_output_loss: 12.0426 - y1_output_mae: 2.4679 - y2_output_loss: 11.2645 - y2_output_mae: 2.4185 - val_loss: 25.2206 - val_y1_output_loss: 7.9925 - val_y1_output_mae: 2.2065 - val_y2_output_loss: 17.6945 - val_y2_output_mae: 3.1245
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.8123 - y1_output_loss: 9.1837 - y1_output_mae: 2.2191 - y2_output_loss: 10.6190 - y2_output_mae: 2.3205 - val_loss: 21.3628 - val_y1_output_loss: 5.6978 - val_y1_output_mae: 1.8325 - val_y2_output_loss: 16.0974 - val_y2_output_mae: 2.9494
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.0887 - y1_output_loss: 11.9345 - y1_output_mae: 2.5579 - y2_output_loss: 12.0970 - y2_output_mae: 2.4928 - val_loss: 18.7362 - val_y1_output_loss: 5.3025 - val_y1_output_mae: 1.8313 - val_y2_output_loss: 13.7822 - val_y2_output_mae: 2.7394
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.7798 - y1_output_loss: 11.5065 - y1_output_mae: 2.4437 - y2_output_loss: 11.4161 - y2_output_mae: 2.4875 - val_loss: 26.1751 - val_y1_output_loss: 6.0049 - val_y1_output_mae: 1.8794 - val_y2_output_loss: 20.6547 - val_y2_output_mae: 3.3668
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.9111 - y1_output_loss: 10.7200 - y1_output_mae: 2.4133 - y2_output_loss: 11.1610 - y2_output_mae: 2.4412 - val_loss: 29.0162 - val_y1_output_loss: 7.8154 - val_y1_output_mae: 2.2014 - val_y2_output_loss: 21.7905 - val_y2_output_mae: 3.4994
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.3819 - y1_output_loss: 11.0929 - y1_output_mae: 2.2854 - y2_output_loss: 13.4657 - y2_output_mae: 2.6480 - val_loss: 23.8858 - val_y1_output_loss: 4.4019 - val_y1_output_mae: 1.6321 - val_y2_output_loss: 19.9763 - val_y2_output_mae: 3.3978
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.8027 - y1_output_loss: 11.2890 - y1_output_mae: 2.3622 - y2_output_loss: 10.6206 - y2_output_mae: 2.3443 - val_loss: 26.8669 - val_y1_output_loss: 7.9547 - val_y1_output_mae: 2.1460 - val_y2_output_loss: 19.3737 - val_y2_output_mae: 3.2545
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.2714 - y1_output_loss: 9.4666 - y1_output_mae: 2.1964 - y2_output_loss: 10.8812 - y2_output_mae: 2.4224 - val_loss: 24.4446 - val_y1_output_loss: 5.3845 - val_y1_output_mae: 1.7843 - val_y2_output_loss: 19.5315 - val_y2_output_mae: 3.3136
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.7430 - y1_output_loss: 10.6145 - y1_output_mae: 2.3157 - y2_output_loss: 12.0917 - y2_output_mae: 2.5416 - val_loss: 28.5683 - val_y1_output_loss: 9.5510 - val_y1_output_mae: 2.4016 - val_y2_output_loss: 19.6074 - val_y2_output_mae: 3.2959
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.2667 - y1_output_loss: 11.0264 - y1_output_mae: 2.4273 - y2_output_loss: 14.2899 - y2_output_mae: 2.6123 - val_loss: 17.8282 - val_y1_output_loss: 3.9434 - val_y1_output_mae: 1.4498 - val_y2_output_loss: 14.2909 - val_y2_output_mae: 2.7148
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.9167 - y1_output_loss: 9.8555 - y1_output_mae: 2.2087 - y2_output_loss: 10.1198 - y2_output_mae: 2.3030 - val_loss: 17.3866 - val_y1_output_loss: 3.4256 - val_y1_output_mae: 1.3336 - val_y2_output_loss: 14.3308 - val_y2_output_mae: 2.7341
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.8500 - y1_output_loss: 11.2267 - y1_output_mae: 2.3780 - y2_output_loss: 12.5618 - y2_output_mae: 2.6578 - val_loss: 19.3433 - val_y1_output_loss: 3.7727 - val_y1_output_mae: 1.4388 - val_y2_output_loss: 15.9833 - val_y2_output_mae: 2.9432
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.0685 - y1_output_loss: 11.6963 - y1_output_mae: 2.3516 - y2_output_loss: 11.3460 - y2_output_mae: 2.3609 - val_loss: 25.2593 - val_y1_output_loss: 6.2404 - val_y1_output_mae: 1.8917 - val_y2_output_loss: 19.4620 - val_y2_output_mae: 3.2685
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.1875 - y1_output_loss: 11.5222 - y1_output_mae: 2.4309 - y2_output_loss: 11.6951 - y2_output_mae: 2.4746 - val_loss: 24.3744 - val_y1_output_loss: 4.4683 - val_y1_output_mae: 1.5894 - val_y2_output_loss: 20.4361 - val_y2_output_mae: 3.3876
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.9224 - y1_output_loss: 10.0810 - y1_output_mae: 2.2424 - y2_output_loss: 10.8066 - y2_output_mae: 2.3912 - val_loss: 22.1976 - val_y1_output_loss: 4.9927 - val_y1_output_mae: 1.7594 - val_y2_output_loss: 17.6367 - val_y2_output_mae: 3.1532
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.2404 - y1_output_loss: 11.5142 - y1_output_mae: 2.5175 - y2_output_loss: 10.7855 - y2_output_mae: 2.3855 - val_loss: 23.9283 - val_y1_output_loss: 6.6093 - val_y1_output_mae: 1.9385 - val_y2_output_loss: 17.7930 - val_y2_output_mae: 3.0868
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5945 - y1_output_loss: 9.1511 - y1_output_mae: 2.2608 - y2_output_loss: 10.3901 - y2_output_mae: 2.3478 - val_loss: 22.8178 - val_y1_output_loss: 5.3125 - val_y1_output_mae: 1.7505 - val_y2_output_loss: 18.0048 - val_y2_output_mae: 3.1511
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.1112 - y1_output_loss: 12.4425 - y1_output_mae: 2.5338 - y2_output_loss: 11.6076 - y2_output_mae: 2.4433 - val_loss: 27.0617 - val_y1_output_loss: 6.5629 - val_y1_output_mae: 1.9431 - val_y2_output_loss: 21.0869 - val_y2_output_mae: 3.4237
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.5261 - y1_output_loss: 10.7102 - y1_output_mae: 2.3174 - y2_output_loss: 10.7702 - y2_output_mae: 2.3694 - val_loss: 26.9897 - val_y1_output_loss: 7.5556 - val_y1_output_mae: 2.1125 - val_y2_output_loss: 19.9686 - val_y2_output_mae: 3.3327
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.9906 - y1_output_loss: 9.9626 - y1_output_mae: 2.2528 - y2_output_loss: 12.0923 - y2_output_mae: 2.4865 - val_loss: 27.3165 - val_y1_output_loss: 6.1096 - val_y1_output_mae: 1.8305 - val_y2_output_loss: 21.7321 - val_y2_output_mae: 3.4527
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.9623 - y1_output_loss: 10.3282 - y1_output_mae: 2.3355 - y2_output_loss: 10.6523 - y2_output_mae: 2.3949 - val_loss: 21.3716 - val_y1_output_loss: 5.7437 - val_y1_output_mae: 1.8479 - val_y2_output_loss: 16.0431 - val_y2_output_mae: 2.9436
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.1085 - y1_output_loss: 11.1564 - y1_output_mae: 2.4140 - y2_output_loss: 9.8889 - y2_output_mae: 2.2943 - val_loss: 32.5172 - val_y1_output_loss: 9.2937 - val_y1_output_mae: 2.3699 - val_y2_output_loss: 23.8527 - val_y2_output_mae: 3.6858
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.4347 - y1_output_loss: 9.8488 - y1_output_mae: 2.2807 - y2_output_loss: 10.5989 - y2_output_mae: 2.2254 - val_loss: 34.0507 - val_y1_output_loss: 9.4342 - val_y1_output_mae: 2.3180 - val_y2_output_loss: 25.3649 - val_y2_output_mae: 3.7636
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.1675 - y1_output_loss: 13.4204 - y1_output_mae: 2.5490 - y2_output_loss: 9.7256 - y2_output_mae: 2.2297 - val_loss: 26.2378 - val_y1_output_loss: 6.7168 - val_y1_output_mae: 2.0000 - val_y2_output_loss: 20.0182 - val_y2_output_mae: 3.3608
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2636 - y1_output_loss: 9.6234 - y1_output_mae: 2.3011 - y2_output_loss: 9.5935 - y2_output_mae: 2.1997 - val_loss: 18.2941 - val_y1_output_loss: 2.9909 - val_y1_output_mae: 1.3140 - val_y2_output_loss: 15.6279 - val_y2_output_mae: 3.0003
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.5161 - y1_output_loss: 12.5497 - y1_output_mae: 2.4848 - y2_output_loss: 10.8914 - y2_output_mae: 2.3470 - val_loss: 19.3570 - val_y1_output_loss: 4.1898 - val_y1_output_mae: 1.5137 - val_y2_output_loss: 15.5781 - val_y2_output_mae: 2.8531
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.7032 - y1_output_loss: 9.9892 - y1_output_mae: 2.2078 - y2_output_loss: 11.6532 - y2_output_mae: 2.3941 - val_loss: 13.7799 - val_y1_output_loss: 3.2050 - val_y1_output_mae: 1.3104 - val_y2_output_loss: 10.8771 - val_y2_output_mae: 2.3274
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.0101 - y1_output_loss: 10.1024 - y1_output_mae: 2.3482 - y2_output_loss: 10.8989 - y2_output_mae: 2.4178 - val_loss: 23.3069 - val_y1_output_loss: 3.4763 - val_y1_output_mae: 1.3650 - val_y2_output_loss: 20.3130 - val_y2_output_mae: 3.4352
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.1564 - y1_output_loss: 10.7876 - y1_output_mae: 2.2789 - y2_output_loss: 10.3159 - y2_output_mae: 2.3009 - val_loss: 19.7164 - val_y1_output_loss: 4.8735 - val_y1_output_mae: 1.6534 - val_y2_output_loss: 15.2693 - val_y2_output_mae: 2.8418
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.4484 - y1_output_loss: 7.8520 - y1_output_mae: 2.0438 - y2_output_loss: 10.5652 - y2_output_mae: 2.3401 - val_loss: 19.6919 - val_y1_output_loss: 4.3439 - val_y1_output_mae: 1.5839 - val_y2_output_loss: 15.7103 - val_y2_output_mae: 2.9028
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7760 - y1_output_loss: 7.8432 - y1_output_mae: 2.0089 - y2_output_loss: 9.9437 - y2_output_mae: 2.2068 - val_loss: 14.0847 - val_y1_output_loss: 2.7210 - val_y1_output_mae: 1.1971 - val_y2_output_loss: 11.6596 - val_y2_output_mae: 2.4089
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.6524 - y1_output_loss: 11.3658 - y1_output_mae: 2.3864 - y2_output_loss: 10.2234 - y2_output_mae: 2.3128 - val_loss: 15.3256 - val_y1_output_loss: 2.8107 - val_y1_output_mae: 1.2217 - val_y2_output_loss: 12.8372 - val_y2_output_mae: 2.5869
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.1527 - y1_output_loss: 10.9878 - y1_output_mae: 2.4250 - y2_output_loss: 10.1743 - y2_output_mae: 2.2988 - val_loss: 25.7326 - val_y1_output_loss: 5.7257 - val_y1_output_mae: 1.8225 - val_y2_output_loss: 20.4619 - val_y2_output_mae: 3.4350
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.7794 - y1_output_loss: 9.4159 - y1_output_mae: 2.2116 - y2_output_loss: 9.3341 - y2_output_mae: 2.1892 - val_loss: 25.3653 - val_y1_output_loss: 6.3306 - val_y1_output_mae: 1.8935 - val_y2_output_loss: 19.5186 - val_y2_output_mae: 3.3292
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2634 - y1_output_loss: 9.9875 - y1_output_mae: 2.2472 - y2_output_loss: 9.2304 - y2_output_mae: 2.1516 - val_loss: 34.3277 - val_y1_output_loss: 9.3505 - val_y1_output_mae: 2.2938 - val_y2_output_loss: 25.4988 - val_y2_output_mae: 3.8735
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.0205 - y1_output_loss: 9.0723 - y1_output_mae: 2.1303 - y2_output_loss: 8.9084 - y2_output_mae: 2.1728 - val_loss: 16.5310 - val_y1_output_loss: 3.4756 - val_y1_output_mae: 1.4199 - val_y2_output_loss: 13.3764 - val_y2_output_mae: 2.6709
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.9160 - y1_output_loss: 9.2379 - y1_output_mae: 2.1525 - y2_output_loss: 10.6631 - y2_output_mae: 2.3263 - val_loss: 17.3923 - val_y1_output_loss: 2.4775 - val_y1_output_mae: 1.1383 - val_y2_output_loss: 15.2815 - val_y2_output_mae: 2.8606
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.2374 - y1_output_loss: 10.4218 - y1_output_mae: 2.3192 - y2_output_loss: 10.8299 - y2_output_mae: 2.4174 - val_loss: 15.6048 - val_y1_output_loss: 4.5709 - val_y1_output_mae: 1.6448 - val_y2_output_loss: 11.3746 - val_y2_output_mae: 2.4039
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.8869 - y1_output_loss: 8.6448 - y1_output_mae: 2.1411 - y2_output_loss: 10.2190 - y2_output_mae: 2.3166 - val_loss: 19.0193 - val_y1_output_loss: 3.8546 - val_y1_output_mae: 1.4442 - val_y2_output_loss: 15.5648 - val_y2_output_mae: 2.8581
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.0091 - y1_output_loss: 7.8819 - y1_output_mae: 2.0259 - y2_output_loss: 10.1018 - y2_output_mae: 2.3137 - val_loss: 27.4400 - val_y1_output_loss: 5.4781 - val_y1_output_mae: 1.7682 - val_y2_output_loss: 22.4853 - val_y2_output_mae: 3.6094
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9918 - y1_output_loss: 8.6781 - y1_output_mae: 2.1416 - y2_output_loss: 9.3149 - y2_output_mae: 2.1680 - val_loss: 24.1585 - val_y1_output_loss: 5.2086 - val_y1_output_mae: 1.7397 - val_y2_output_loss: 19.4837 - val_y2_output_mae: 3.2835
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.0438 - y1_output_loss: 9.7729 - y1_output_mae: 2.2766 - y2_output_loss: 8.3267 - y2_output_mae: 2.0792 - val_loss: 22.1241 - val_y1_output_loss: 6.2644 - val_y1_output_mae: 1.8669 - val_y2_output_loss: 16.3123 - val_y2_output_mae: 2.9227
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.5267 - y1_output_loss: 8.8034 - y1_output_mae: 2.0076 - y2_output_loss: 9.7991 - y2_output_mae: 2.1833 - val_loss: 16.4407 - val_y1_output_loss: 2.6056 - val_y1_output_mae: 1.1653 - val_y2_output_loss: 14.1594 - val_y2_output_mae: 2.6847
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.7987 - y1_output_loss: 7.9800 - y1_output_mae: 2.0274 - y2_output_loss: 9.7893 - y2_output_mae: 2.3415 - val_loss: 30.1238 - val_y1_output_loss: 4.8273 - val_y1_output_mae: 1.6054 - val_y2_output_loss: 25.8466 - val_y2_output_mae: 3.9354
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.5529 - y1_output_loss: 10.2633 - y1_output_mae: 2.3303 - y2_output_loss: 10.2989 - y2_output_mae: 2.3582 - val_loss: 19.5262 - val_y1_output_loss: 8.0516 - val_y1_output_mae: 2.1641 - val_y2_output_loss: 11.9318 - val_y2_output_mae: 2.4407
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.9673 - y1_output_loss: 7.5213 - y1_output_mae: 1.9719 - y2_output_loss: 8.4208 - y2_output_mae: 2.0943 - val_loss: 29.5230 - val_y1_output_loss: 6.7017 - val_y1_output_mae: 1.9394 - val_y2_output_loss: 23.3702 - val_y2_output_mae: 3.6878
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.8263 - y1_output_loss: 9.1500 - y1_output_mae: 2.0932 - y2_output_loss: 9.6774 - y2_output_mae: 2.1572 - val_loss: 22.6978 - val_y1_output_loss: 7.3219 - val_y1_output_mae: 2.0467 - val_y2_output_loss: 15.7563 - val_y2_output_mae: 2.8919
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1511 - y1_output_loss: 9.1380 - y1_output_mae: 2.1631 - y2_output_loss: 10.0198 - y2_output_mae: 2.2797 - val_loss: 28.6696 - val_y1_output_loss: 5.5998 - val_y1_output_mae: 1.7097 - val_y2_output_loss: 23.6404 - val_y2_output_mae: 3.6221
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6443 - y1_output_loss: 8.4105 - y1_output_mae: 2.1415 - y2_output_loss: 9.3009 - y2_output_mae: 2.1930 - val_loss: 22.2205 - val_y1_output_loss: 5.3314 - val_y1_output_mae: 1.7432 - val_y2_output_loss: 17.3536 - val_y2_output_mae: 3.0620
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.2013 - y1_output_loss: 9.9451 - y1_output_mae: 2.2416 - y2_output_loss: 9.2652 - y2_output_mae: 2.2223 - val_loss: 21.3532 - val_y1_output_loss: 5.0519 - val_y1_output_mae: 1.6545 - val_y2_output_loss: 16.7672 - val_y2_output_mae: 2.9914
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9970 - y1_output_loss: 8.4034 - y1_output_mae: 2.0555 - y2_output_loss: 10.5439 - y2_output_mae: 2.2977 - val_loss: 24.5274 - val_y1_output_loss: 5.5028 - val_y1_output_mae: 1.7723 - val_y2_output_loss: 19.5249 - val_y2_output_mae: 3.3420
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.1166 - y1_output_loss: 7.9246 - y1_output_mae: 2.0362 - y2_output_loss: 9.1486 - y2_output_mae: 2.1754 - val_loss: 24.2783 - val_y1_output_loss: 5.6513 - val_y1_output_mae: 1.7369 - val_y2_output_loss: 19.1105 - val_y2_output_mae: 3.2167
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7620 - y1_output_loss: 7.7820 - y1_output_mae: 1.9877 - y2_output_loss: 7.9801 - y2_output_mae: 2.1039 - val_loss: 26.5401 - val_y1_output_loss: 6.2233 - val_y1_output_mae: 1.8425 - val_y2_output_loss: 20.8355 - val_y2_output_mae: 3.3851
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.7068 - y1_output_loss: 9.3627 - y1_output_mae: 2.1621 - y2_output_loss: 9.2961 - y2_output_mae: 2.1614 - val_loss: 30.2571 - val_y1_output_loss: 9.9213 - val_y1_output_mae: 2.4213 - val_y2_output_loss: 20.8896 - val_y2_output_mae: 3.3634
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.2867 - y1_output_loss: 7.6401 - y1_output_mae: 1.9621 - y2_output_loss: 7.6382 - y2_output_mae: 1.9559 - val_loss: 24.6012 - val_y1_output_loss: 8.3728 - val_y1_output_mae: 2.1521 - val_y2_output_loss: 16.7089 - val_y2_output_mae: 2.9325
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.6715 - y1_output_loss: 9.2820 - y1_output_mae: 2.1945 - y2_output_loss: 9.4183 - y2_output_mae: 2.1324 - val_loss: 22.0085 - val_y1_output_loss: 4.4742 - val_y1_output_mae: 1.5357 - val_y2_output_loss: 17.9931 - val_y2_output_mae: 3.0922
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4164 - y1_output_loss: 8.0798 - y1_output_mae: 2.0762 - y2_output_loss: 9.2973 - y2_output_mae: 2.1409 - val_loss: 22.2613 - val_y1_output_loss: 4.2737 - val_y1_output_mae: 1.4984 - val_y2_output_loss: 18.4693 - val_y2_output_mae: 3.2107
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.1373 - y1_output_loss: 8.0738 - y1_output_mae: 2.0049 - y2_output_loss: 8.0236 - y2_output_mae: 2.0793 - val_loss: 25.5935 - val_y1_output_loss: 9.1290 - val_y1_output_mae: 2.2612 - val_y2_output_loss: 17.0007 - val_y2_output_mae: 3.0060
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.3375 - y1_output_loss: 8.9414 - y1_output_mae: 2.0788 - y2_output_loss: 9.4290 - y2_output_mae: 2.2318 - val_loss: 33.0359 - val_y1_output_loss: 7.7839 - val_y1_output_mae: 2.1047 - val_y2_output_loss: 25.8293 - val_y2_output_mae: 3.9291
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.5624 - y1_output_loss: 8.5289 - y1_output_mae: 2.0790 - y2_output_loss: 9.0408 - y2_output_mae: 1.9965 - val_loss: 23.1687 - val_y1_output_loss: 7.0771 - val_y1_output_mae: 1.9408 - val_y2_output_loss: 16.5679 - val_y2_output_mae: 2.9624
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0569 - y1_output_loss: 7.4815 - y1_output_mae: 1.9502 - y2_output_loss: 9.5264 - y2_output_mae: 2.1537 - val_loss: 21.5119 - val_y1_output_loss: 4.3845 - val_y1_output_mae: 1.4832 - val_y2_output_loss: 17.6032 - val_y2_output_mae: 3.0063
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.5087 - y1_output_loss: 8.1499 - y1_output_mae: 2.0625 - y2_output_loss: 8.3025 - y2_output_mae: 2.0669 - val_loss: 25.6749 - val_y1_output_loss: 6.3969 - val_y1_output_mae: 1.8796 - val_y2_output_loss: 19.7872 - val_y2_output_mae: 3.3035
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8585 - y1_output_loss: 7.4918 - y1_output_mae: 1.9774 - y2_output_loss: 8.3772 - y2_output_mae: 2.1022 - val_loss: 27.0832 - val_y1_output_loss: 6.1765 - val_y1_output_mae: 1.7949 - val_y2_output_loss: 21.4577 - val_y2_output_mae: 3.4357
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.7531 - y1_output_loss: 8.2530 - y1_output_mae: 2.0846 - y2_output_loss: 8.4712 - y2_output_mae: 2.0563 - val_loss: 21.8896 - val_y1_output_loss: 3.6773 - val_y1_output_mae: 1.3604 - val_y2_output_loss: 18.6028 - val_y2_output_mae: 3.2101
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.8678 - y1_output_loss: 9.3113 - y1_output_mae: 2.2148 - y2_output_loss: 9.6220 - y2_output_mae: 2.1889 - val_loss: 21.0564 - val_y1_output_loss: 4.4583 - val_y1_output_mae: 1.5276 - val_y2_output_loss: 17.0030 - val_y2_output_mae: 3.0326
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.6235 - y1_output_loss: 8.1555 - y1_output_mae: 1.9723 - y2_output_loss: 8.4907 - y2_output_mae: 2.1026 - val_loss: 19.0315 - val_y1_output_loss: 4.9824 - val_y1_output_mae: 1.6331 - val_y2_output_loss: 14.4800 - val_y2_output_mae: 2.7330
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.5038 - y1_output_loss: 7.9014 - y1_output_mae: 1.9775 - y2_output_loss: 9.5923 - y2_output_mae: 2.1500 - val_loss: 15.2704 - val_y1_output_loss: 3.7672 - val_y1_output_mae: 1.3834 - val_y2_output_loss: 11.8838 - val_y2_output_mae: 2.4076

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Evaluamos el modelo
results = model.evaluate(X_test, [y1_test, y2_test], verbose=0)

test_loss, y1_loss, y2_loss, test_mae_heating, test_mae_cooling = results

print(f"Total Test Loss: {test_loss:.4f}")
print(f"Heating Loss: {y1_loss:.4f}, Cooling Loss: {y2_loss:.4f}")
print(f"Test MAE for Heating Load: {test_mae_heating:.4f} Wh")
print(f"Test MAE for Cooling Load: {test_mae_cooling:.4f} Wh")
# Out:
# Total Test Loss: 15.2704
# Heating Loss: 3.7672, Cooling Loss: 11.8838
# Test MAE for Heating Load: 1.3834 Wh
# Test MAE for Cooling Load: 2.4076 Wh

# %%
import matplotlib.pyplot as plt


print(history.history.keys())

# ---- Graficamos el loss, que en este caso decidimos que fuera el MSE
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Total Training Loss')
plt.plot(history.history['val_loss'], label='Total Validation Loss')
plt.plot(history.history['y1_output_loss'], label='Heating Training Loss')
plt.plot(history.history['val_y1_output_loss'], label='Heating Validation Loss')
plt.plot(history.history['y2_output_loss'], label='Cooling Training Loss')
plt.plot(history.history['val_y2_output_loss'], label='Cooling Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# Graficamos el MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history['y1_output_mae'], label='Heating Training MAE')
plt.plot(history.history['val_y1_output_mae'], label='Heating Validation MAE')
plt.plot(history.history['y2_output_mae'], label='Cooling Training MAE')
plt.plot(history.history['val_y2_output_mae'], label='Cooling Validation MAE')
plt.title('Model MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE (Wh)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Realizar predicciones
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

#Como tenemos dos targets, las predicciones hay que separarlas
y_train_pred_heating = y_pred_train[0].flatten()
y_train_pred_cooling = y_pred_train[1].flatten()

y_test_pred_heating = y_pred_test[0].flatten()
y_test_pred_cooling = y_pred_test[1].flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
#Metricas de performance para heating

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

def regression_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(root_mean_squared_error(y_true, y_pred))
    return r2, mae, rmse

# Metricas train
r2_train_heat, mae_train_heat, rmse_train_heat = regression_metrics(y1_train, y_train_pred_heating)
r2_train_cool, mae_train_cool, rmse_train_cool = regression_metrics(y2_train, y_train_pred_cooling)
print("=== Train Performance ===")
print(f"Heating Load: R²={r2_train_heat:.3f}, MAE={mae_train_heat:.3f}, RMSE={rmse_train_heat:.3f}")
print(f"Cooling Load: R²={r2_train_cool:.3f}, MAE={mae_train_cool:.3f}, RMSE={rmse_train_cool:.3f}")

# metricas test
r2_test_heat, mae_test_heat, rmse_test_heat = regression_metrics(y1_test, y_test_pred_heating)
r2_test_cool, mae_test_cool, rmse_test_cool = regression_metrics(y2_test, y_test_pred_cooling)
print("\n=== Test Performance ===")
print(f"Heating Load: R²={r2_test_heat:.3f}, MAE={mae_test_heat:.3f}, RMSE={rmse_test_heat:.3f}")
print(f"Cooling Load: R²={r2_test_cool:.3f}, MAE={mae_test_cool:.3f}, RMSE={rmse_test_cool:.3f}")
# Out:
# === Train Performance ===
# Heating Load: R²=0.968, MAE=1.315, RMSE=1.336
# Cooling Load: R²=0.888, MAE=2.169, RMSE=1.779
#
# === Test Performance ===
# Heating Load: R²=0.965, MAE=1.383, RMSE=1.387
# Cooling Load: R²=0.875, MAE=2.408, RMSE=1.844

# %% [markdown]
# #### Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models

def build_model(input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # Capas compartidas
    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Heating
    h = layers.Dense(64, activation='relu')(x)
    h = layers.Dropout(0.2)(h)
    h = layers.Dense(32, activation='relu')(h)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling
    c = layers.Dense(64, activation='relu')(x)
    c = layers.Dropout(0.2)(c)
    c = layers.Dense(32, activation='relu')(c)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler
from numpy import sqrt

#KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

r2_heat, r2_cool = [], []
mae_heat, mae_cool = [], []
rmse_heat, rmse_cool = [], []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n Fold {fold+1}")
    
    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_heat, y_val_heat = df['Y1'][train_idx], df['Y1'][val_idx]
    y_train_cool, y_val_cool = df['Y2'][train_idx], df['Y2'][val_idx]
    
    # Scale inputs
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    
    # Build & train model
    model = build_model(X.shape[1])
    model.fit(
        X_train, [y_train_heat, y_train_cool],
        epochs=80, batch_size=32, verbose=0
    )
    
    # Predict
    y_pred_heat, y_pred_cool = model.predict(X_val, verbose=0)
    
    # Flatten
    y_pred_heat, y_pred_cool = y_pred_heat.flatten(), y_pred_cool.flatten()
    
    # Compute metrics
    r2_heat.append(r2_score(y_val_heat, y_pred_heat))
    r2_cool.append(r2_score(y_val_cool, y_pred_cool))
    mae_heat.append(mean_absolute_error(y_val_heat, y_pred_heat))
    mae_cool.append(mean_absolute_error(y_val_cool, y_pred_cool))
    rmse_heat.append(sqrt(mean_squared_error(y_val_heat, y_pred_heat)))
    rmse_cool.append(sqrt(mean_squared_error(y_val_cool, y_pred_cool)))
# Out:
#  Fold 1
#
#  Fold 2
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000016DFB20AB00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 3
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000016D844BCA60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 4
#
#  Fold 5

# %%
print("\n=== Cross-Validation Results ===")
print(f"Heating Load: R2={np.mean(r2_heat):.3f}±{np.std(r2_heat):.3f}, "
      f"MAE={np.mean(mae_heat):.3f}, RMSE={np.mean(rmse_heat):.3f}")
print(f"Cooling Load: R2={np.mean(r2_cool):.3f}±{np.std(r2_cool):.3f}, "
      f"MAE={np.mean(mae_cool):.3f}, RMSE={np.mean(rmse_cool):.3f}")
# Out:
# === Cross-Validation Results ===
# Heating Load: R2=0.955±0.015, MAE=1.601, RMSE=2.108
# Cooling Load: R2=0.918±0.031, MAE=1.916, RMSE=2.654

# %% [markdown]
# ## Tuneo de hiperparametros
#
# Especificamente diseniado para redes neuronales

# %%
# Random Serach
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers

df = pd.read_csv("ENB2012_data.csv")
X_full = df[['X1','X2','X3','X4','X5','X6','X7','X8']].values
y1_full = df['Y1'].values
y2_full = df['Y2'].values

scaler = StandardScaler()
X_full = scaler.fit_transform(X_full)


X_train_full, X_test_full, y1_train_full, y1_test_full, y2_train_full, y2_test_full = train_test_split(
    X_full, y1_full, y2_full, test_size=0.2, random_state=42
)


# Definimos el contructor del modelo

def build_random_model(params, input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # compartidas
    x = input_layer
    for i in range(params['n_shared_layers']):
        x = layers.Dense(params['n_shared_units'], activation='relu')(x)
        x = layers.Dropout(params['dropout_rate'])(x)
    
    # Heating 
    h = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling 
    c = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    
    opt = optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(
        optimizer=opt,
        loss={'heating_output': 'mse', 'cooling_output': 'mse'},
        metrics={'heating_output': 'mae', 'cooling_output': 'mae'}
    )
    
    return model


# Espacio para el random search

param_distributions = {
    'n_shared_layers': [1, 2, 3],
    'n_shared_units': [32, 64, 128, 256],
    'dropout_rate': [0.0, 0.1, 0.2, 0.3, 0.4],
    'learning_rate': [1e-4, 5e-4, 1e-3, 5e-3],
    'batch_size': [16, 32, 64]
}


n_trials = 5
results = []

print("\n Empezamos Random Search")
for i in range(n_trials):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i+1}/{n_trials} with params: {params}")
    
    X_train_rs, X_val_rs, y1_train_rs, y1_val_rs, y2_train_rs, y2_val_rs = train_test_split(
        X_train_full, y1_train_full, y2_train_full, test_size=0.2, random_state=i
    )
    
    model = build_random_model(params, X_train_rs.shape[1])
    history = model.fit(
        X_train_rs, [y1_train_rs, y2_train_rs],
        validation_data=(X_val_rs, [y1_val_rs, y2_val_rs]),
        epochs=50, batch_size=params['batch_size'], verbose=0
    )
    
    val_loss = np.mean(history.history['val_loss'][-5:])
    results.append((params, val_loss))
    print(f"Validation Loss: {val_loss:.4f}")

# Resultados
results.sort(key=lambda x: x[1])
print("\n Results")
for rank, (params, loss) in enumerate(results, 1):
    print(f"{rank:2d}) Val Loss={loss:.4f} | Params={params}")

best_params, best_loss = results[0]
print("\n Mejor configuracion:")
print(best_params)
print(f"Validation Loss: {best_loss:.4f}")
# Out:
#  Empezamos Random Search
#
# Trial 1/5 with params: {'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.005, 'batch_size': 16}
# Validation Loss: 6.5265
#
# Trial 2/5 with params: {'n_shared_layers': 1, 'n_shared_units': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 32}
# Validation Loss: 19.2261
#
# Trial 3/5 with params: {'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.0005, 'batch_size': 16}
# Validation Loss: 17.8299
#
# Trial 4/5 with params: {'n_shared_layers': 3, 'n_shared_units': 256, 'dropout_rate': 0.4, 'learning_rate': 0.005, 'batch_size': 32}
# Validation Loss: 13.2737
#
# Trial 5/5 with params: {'n_shared_layers': 2, 'n_shared_units': 128, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 64}
# Validation Loss: 22.0125
#
#  Results
#  1) Val Loss=6.5265 | Params={'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.005, 'batch_size': 16}
#  2) Val Loss=13.2737 | Params={'n_shared_layers': 3, 'n_shared_units': 256, 'dropout_rate': 0.4, 'learning_rate': 0.005, 'batch_size': 32}
#  3) Val Loss=17.8299 | Params={'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.0005, 'batch_size': 16}
#  4) Val Loss=19.2261 | Params={'n_shared_layers': 1, 'n_shared_units': 256, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 32}
#  5) Val Loss=22.0125 | Params={'n_shared_layers': 2, 'n_shared_units': 128, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 64}
#
#  Mejor configuracion:
# {'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.005, 'batch_size': 16}
# Validation Loss: 6.5265

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
